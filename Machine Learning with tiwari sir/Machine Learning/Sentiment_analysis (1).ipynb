# %%
import os
# Supress Warnings
import warnings
warnings.filterwarnings('ignore')

#loading all necessary libraries
import numpy as np
import pandas as pd

import pandas as pd
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import re


os.chdir(r"/content/sample_data/")

df = pd.read_csv("movie_review.csv")

lemma = WordNetLemmatizer()
stop_words = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def text_prep(x):
     corp = str(x).lower()
     corp = re.sub('[^a-zA-Z]+',' ', corp).strip()
     tokens = word_tokenize(corp)
     words = [t for t in tokens if t not in stop_words]
     lemmatize = [lemma.lemmatize(w) for w in words]

     return lemmatize

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
preprocess_tag = [text_prep(i) for i in df['text']]
df["preprocess_txt"] = preprocess_tag

# %%
import pandas as pd
import os
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
sent = SentimentIntensityAnalyzer()

os.chdir(r"/content/sample_data/")

data = pd.read_csv("movie_review.csv")
data.head()
# Out:
#    fold_id cv_tag  html_id  sent_id  \
# 0        0  cv000    29590        0
# 1        0  cv000    29590        1
# 2        0  cv000    29590        2
# 3        0  cv000    29590        3
# 4        0  cv000    29590        4
#
#                                                 text  tag
# 0  films adapted from comic books have had plenty...  pos
# 1  for starters , it was created by alan moore ( ...  pos
# 2  to say moore and campbell thoroughly researche...  pos
# 3  the book ( or " graphic novel , " if you will ...  pos
# 4  in other words , don't dismiss this film becau...  pos

# %%
polarity = [round(sent.polarity_scores(i)['compound'], 2) for i in data['text']]
data['sentiment_score'] = polarity
data.head()
# Out:
#    fold_id cv_tag  html_id  sent_id  \
# 0        0  cv000    29590        0
# 1        0  cv000    29590        1
# 2        0  cv000    29590        2
# 3        0  cv000    29590        3
# 4        0  cv000    29590        4
#
#                                                 text  tag  sentiment_score
# 0  films adapted from comic books have had plenty...  pos            -0.53
# 1  for starters , it was created by alan moore ( ...  pos             0.25
# 2  to say moore and campbell thoroughly researche...  pos             0.13
# 3  the book ( or " graphic novel , " if you will ...  pos             0.17
# 4  in other words , don't dismiss this film becau...  pos             0.00
